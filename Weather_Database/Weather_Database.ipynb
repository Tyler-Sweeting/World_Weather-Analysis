# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats, lngs)

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities = []

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
       cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 790

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]       
        
        # Append the city information into the city_data list
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_description})

    
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | sangar
# Processing Record 2 of Set 1 | doka
# Processing Record 3 of Set 1 | lichuan
# Processing Record 4 of Set 1 | tromso
# Processing Record 5 of Set 1 | harrismith
# Processing Record 6 of Set 1 | ushuaia
# Processing Record 7 of Set 1 | rikitea
# Processing Record 8 of Set 1 | batemans bay
# Processing Record 9 of Set 1 | kapaa
# Processing Record 10 of Set 1 | saint-joseph
# Processing Record 11 of Set 1 | puerto ayora
# Processing Record 12 of Set 1 | san quintin
# Processing Record 13 of Set 1 | feicheng
# Processing Record 14 of Set 1 | jamestown
# Processing Record 15 of Set 1 | busselton
# Processing Record 16 of Set 1 | mataura
# Processing Record 17 of Set 1 | alihe
# Processing Record 18 of Set 1 | brewer
# Processing Record 19 of Set 1 | yellowknife
# Processing Record 20 of Set 1 | nikolskoye
# Processing Record 21 of Set 1 | warqla
# City not found. Skipping...
# Processing Record 22 of Set 1 | tiarei
# Processing Record 23 of Set 1 | talnakh
# Processing Record 24 of Set 1 | saskylakh
# Processing Record 25 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 26 of Set 1 | qaanaaq
# Processing Record 27 of Set 1 | vaini
# Processing Record 28 of Set 1 | olot
# Processing Record 29 of Set 1 | vanavara
# Processing Record 30 of Set 1 | avera
# Processing Record 31 of Set 1 | bredasdorp
# Processing Record 32 of Set 1 | yanji
# Processing Record 33 of Set 1 | portland
# Processing Record 34 of Set 1 | chokurdakh
# Processing Record 35 of Set 1 | simpang
# Processing Record 36 of Set 1 | hilo
# Processing Record 37 of Set 1 | hithadhoo
# Processing Record 38 of Set 1 | longyearbyen
# Processing Record 39 of Set 1 | albany
# Processing Record 40 of Set 1 | avarua
# Processing Record 41 of Set 1 | loubomo
# Processing Record 42 of Set 1 | buraydah
# Processing Record 43 of Set 1 | hermanus
# Processing Record 44 of Set 1 | ulladulla
# Processing Record 45 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 46 of Set 1 | new norfolk
# Processing Record 47 of Set 1 | port macquarie
# Processing Record 48 of Set 1 | porto recanati
# Processing Record 49 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 50 of Set 1 | taltal
# Processing Record 1 of Set 2 | santa isabel do rio negro
# Processing Record 2 of Set 2 | faanui
# Processing Record 3 of Set 2 | norman wells
# Processing Record 4 of Set 2 | whitianga
# Processing Record 5 of Set 2 | bemidji
# Processing Record 6 of Set 2 | zhongshu
# Processing Record 7 of Set 2 | bluff
# Processing Record 8 of Set 2 | albox
# Processing Record 9 of Set 2 | khatanga
# Processing Record 10 of Set 2 | matay
# Processing Record 11 of Set 2 | auki
# Processing Record 12 of Set 2 | ponta do sol
# Processing Record 13 of Set 2 | mount gambier
# Processing Record 14 of Set 2 | saint pete beach
# Processing Record 15 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 16 of Set 2 | dong xoai
# Processing Record 17 of Set 2 | georgetown
# Processing Record 18 of Set 2 | krasnogorsk
# Processing Record 19 of Set 2 | mahebourg
# Processing Record 20 of Set 2 | atuona
# Processing Record 21 of Set 2 | thompson
# Processing Record 22 of Set 2 | klyuchi
# Processing Record 23 of Set 2 | suleja
# Processing Record 24 of Set 2 | maldonado
# Processing Record 25 of Set 2 | kahului
# Processing Record 26 of Set 2 | bambous virieux
# Processing Record 27 of Set 2 | talcahuano
# Processing Record 28 of Set 2 | camacha
# Processing Record 29 of Set 2 | ixtapa
# Processing Record 30 of Set 2 | dikson
# Processing Record 31 of Set 2 | myitkyina
# Processing Record 32 of Set 2 | vallee-jonction
# City not found. Skipping...
# Processing Record 33 of Set 2 | sorong
# Processing Record 34 of Set 2 | camana
# Processing Record 35 of Set 2 | barrow
# Processing Record 36 of Set 2 | acapulco
# Processing Record 37 of Set 2 | klaksvik
# Processing Record 38 of Set 2 | souillac
# Processing Record 39 of Set 2 | mar del plata
# Processing Record 40 of Set 2 | butaritari
# Processing Record 41 of Set 2 | thinadhoo
# Processing Record 42 of Set 2 | nogliki
# Processing Record 43 of Set 2 | ancud
# Processing Record 44 of Set 2 | puerto leguizamo
# Processing Record 45 of Set 2 | tallahassee
# Processing Record 46 of Set 2 | hobart
# Processing Record 47 of Set 2 | tamiahua
# Processing Record 48 of Set 2 | chapais
# Processing Record 49 of Set 2 | cape town
# Processing Record 50 of Set 2 | hasaki
# Processing Record 1 of Set 3 | puerto escondido
# Processing Record 2 of Set 3 | gazojak
# Processing Record 3 of Set 3 | leningradskiy
# Processing Record 4 of Set 3 | jablah
# Processing Record 5 of Set 3 | kiama
# Processing Record 6 of Set 3 | scanteia
# Processing Record 7 of Set 3 | nouakchott
# Processing Record 8 of Set 3 | blagoyevo
# Processing Record 9 of Set 3 | cabo san lucas
# Processing Record 10 of Set 3 | tasiilaq
# Processing Record 11 of Set 3 | burnie
# Processing Record 12 of Set 3 | cabedelo
# Processing Record 13 of Set 3 | lagoa
# Processing Record 14 of Set 3 | luderitz
# Processing Record 15 of Set 3 | fayaoue
# Processing Record 16 of Set 3 | cidreira
# Processing Record 17 of Set 3 | saldanha
# Processing Record 18 of Set 3 | punta arenas
# Processing Record 19 of Set 3 | dunedin
# Processing Record 20 of Set 3 | dingle
# Processing Record 21 of Set 3 | port elizabeth
# Processing Record 22 of Set 3 | salalah
# Processing Record 23 of Set 3 | sibolga
# Processing Record 24 of Set 3 | muscat
# Processing Record 25 of Set 3 | saquarema
# Processing Record 26 of Set 3 | port alfred
# Processing Record 27 of Set 3 | dawei
# Processing Record 28 of Set 3 | katsuura
# Processing Record 29 of Set 3 | pudozh
# Processing Record 30 of Set 3 | vaitupu
# City not found. Skipping...
# Processing Record 31 of Set 3 | mandalgovi
# Processing Record 32 of Set 3 | eureka
# Processing Record 33 of Set 3 | ribeira grande
# Processing Record 34 of Set 3 | nivala
# Processing Record 35 of Set 3 | upernavik
# Processing Record 36 of Set 3 | den helder
# Processing Record 37 of Set 3 | sechura
# Processing Record 38 of Set 3 | port hedland
# Processing Record 39 of Set 3 | tarakan
# Processing Record 40 of Set 3 | janossomorja
# Processing Record 41 of Set 3 | lompoc
# Processing Record 42 of Set 3 | aklavik
# Processing Record 43 of Set 3 | kailasahar
# City not found. Skipping...
# Processing Record 44 of Set 3 | tuatapere
# Processing Record 45 of Set 3 | coquimbo
# Processing Record 46 of Set 3 | shipunovo
# Processing Record 47 of Set 3 | saint-pierre
# Processing Record 48 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 49 of Set 3 | nanortalik
# Processing Record 50 of Set 3 | lima
# Processing Record 1 of Set 4 | livingston
# Processing Record 2 of Set 4 | babu
# Processing Record 3 of Set 4 | great bend
# Processing Record 4 of Set 4 | chicama
# Processing Record 5 of Set 4 | bastia
# Processing Record 6 of Set 4 | castro
# Processing Record 7 of Set 4 | vallenar
# Processing Record 8 of Set 4 | umzimvubu
# City not found. Skipping...
# Processing Record 9 of Set 4 | pokhara
# Processing Record 10 of Set 4 | bengkulu
# Processing Record 11 of Set 4 | tuktoyaktuk
# Processing Record 12 of Set 4 | buritizeiro
# Processing Record 13 of Set 4 | bethel
# Processing Record 14 of Set 4 | pangnirtung
# Processing Record 15 of Set 4 | erenhot
# Processing Record 16 of Set 4 | kodiak
# Processing Record 17 of Set 4 | bubaque
# Processing Record 18 of Set 4 | mbaiki
# Processing Record 19 of Set 4 | pangody
# Processing Record 20 of Set 4 | grand river south east
# City not found. Skipping...
# Processing Record 21 of Set 4 | narsaq
# Processing Record 22 of Set 4 | isugod
# Processing Record 23 of Set 4 | naples park
# Processing Record 24 of Set 4 | palabuhanratu
# City not found. Skipping...
# Processing Record 25 of Set 4 | yulara
# Processing Record 26 of Set 4 | la ronge
# Processing Record 27 of Set 4 | rawson
# Processing Record 28 of Set 4 | vanimo
# Processing Record 29 of Set 4 | saint-philippe
# Processing Record 30 of Set 4 | roald
# Processing Record 31 of Set 4 | east london
# Processing Record 32 of Set 4 | cabra
# Processing Record 33 of Set 4 | airai
# Processing Record 34 of Set 4 | moca
# Processing Record 35 of Set 4 | provideniya
# Processing Record 36 of Set 4 | saleaula
# City not found. Skipping...
# Processing Record 37 of Set 4 | kudahuvadhoo
# Processing Record 38 of Set 4 | severo-kurilsk
# Processing Record 39 of Set 4 | barawe
# City not found. Skipping...
# Processing Record 40 of Set 4 | vardo
# Processing Record 41 of Set 4 | nuuk
# Processing Record 42 of Set 4 | zhigansk
# Processing Record 43 of Set 4 | ingham
# Processing Record 44 of Set 4 | kpandae
# Processing Record 45 of Set 4 | namatanai
# Processing Record 46 of Set 4 | san cristobal
# Processing Record 47 of Set 4 | broome
# Processing Record 48 of Set 4 | vao
# Processing Record 49 of Set 4 | progreso
# Processing Record 50 of Set 4 | banff
# Processing Record 1 of Set 5 | male
# Processing Record 2 of Set 5 | bara
# Processing Record 3 of Set 5 | kalmunai
# Processing Record 4 of Set 5 | nayoro
# Processing Record 5 of Set 5 | nizhneyansk
# City not found. Skipping...
# Processing Record 6 of Set 5 | vila franca do campo
# Processing Record 7 of Set 5 | krasnovishersk
# Processing Record 8 of Set 5 | pevek
# Processing Record 9 of Set 5 | deep river
# Processing Record 10 of Set 5 | torbay
# Processing Record 11 of Set 5 | meyungs
# City not found. Skipping...
# Processing Record 12 of Set 5 | qaqortoq
# Processing Record 13 of Set 5 | along
# Processing Record 14 of Set 5 | geraldton
# Processing Record 15 of Set 5 | beringovskiy
# Processing Record 16 of Set 5 | sola
# Processing Record 17 of Set 5 | oranjemund
# Processing Record 18 of Set 5 | coihaique
# Processing Record 19 of Set 5 | sneek
# Processing Record 20 of Set 5 | gimli
# Processing Record 21 of Set 5 | claudio
# Processing Record 22 of Set 5 | padang
# Processing Record 23 of Set 5 | ko samui
# Processing Record 24 of Set 5 | kerman
# Processing Record 25 of Set 5 | tabiauea
# City not found. Skipping...
# Processing Record 26 of Set 5 | soc trang
# Processing Record 27 of Set 5 | cherskiy
# Processing Record 28 of Set 5 | sitka
# Processing Record 29 of Set 5 | nam tha
# City not found. Skipping...
# Processing Record 30 of Set 5 | winnemucca
# Processing Record 31 of Set 5 | mogadishu
# Processing Record 32 of Set 5 | carnarvon
# Processing Record 33 of Set 5 | oum hadjer
# Processing Record 34 of Set 5 | isoka
# Processing Record 35 of Set 5 | salinas
# Processing Record 36 of Set 5 | tigbao
# Processing Record 37 of Set 5 | tiksi
# Processing Record 38 of Set 5 | walvis bay
# Processing Record 39 of Set 5 | hobbs
# Processing Record 40 of Set 5 | baillif
# Processing Record 41 of Set 5 | ust-kuyga
# Processing Record 42 of Set 5 | arlit
# Processing Record 43 of Set 5 | jiayuguan
# Processing Record 44 of Set 5 | isangel
# Processing Record 45 of Set 5 | saint george
# Processing Record 46 of Set 5 | tumannyy
# City not found. Skipping...
# Processing Record 47 of Set 5 | cukai
# Processing Record 48 of Set 5 | lorengau
# Processing Record 49 of Set 5 | arraial do cabo
# Processing Record 50 of Set 5 | havoysund
# Processing Record 1 of Set 6 | ewa beach
# Processing Record 2 of Set 6 | hendrina
# Processing Record 3 of Set 6 | inhambane
# Processing Record 4 of Set 6 | marzuq
# Processing Record 5 of Set 6 | husavik
# Processing Record 6 of Set 6 | port blair
# Processing Record 7 of Set 6 | laguna
# Processing Record 8 of Set 6 | faya
# Processing Record 9 of Set 6 | labytnangi
# Processing Record 10 of Set 6 | mandan
# Processing Record 11 of Set 6 | atar
# Processing Record 12 of Set 6 | cleethorpes
# Processing Record 13 of Set 6 | santiago
# Processing Record 14 of Set 6 | grindavik
# Processing Record 15 of Set 6 | sovetskiy
# Processing Record 16 of Set 6 | lexington
# Processing Record 17 of Set 6 | carballo
# Processing Record 18 of Set 6 | kaitangata
# Processing Record 19 of Set 6 | finnsnes
# Processing Record 20 of Set 6 | galgani
# City not found. Skipping...
# Processing Record 21 of Set 6 | constitucion
# Processing Record 22 of Set 6 | sentyabrskiy
# City not found. Skipping...
# Processing Record 23 of Set 6 | ilulissat
# Processing Record 24 of Set 6 | chuy
# Processing Record 25 of Set 6 | mayo
# Processing Record 26 of Set 6 | victoria
# Processing Record 27 of Set 6 | sorland
# Processing Record 28 of Set 6 | lakatoro
# Processing Record 29 of Set 6 | lodja
# Processing Record 30 of Set 6 | inderborskiy
# City not found. Skipping...
# Processing Record 31 of Set 6 | petropavlovsk-kamchatskiy
# Processing Record 32 of Set 6 | awjilah
# Processing Record 33 of Set 6 | canutama
# Processing Record 34 of Set 6 | hamilton
# Processing Record 35 of Set 6 | namibe
# Processing Record 36 of Set 6 | stornoway
# Processing Record 37 of Set 6 | porto novo
# Processing Record 38 of Set 6 | sao felix do xingu
# Processing Record 39 of Set 6 | leh
# Processing Record 40 of Set 6 | turayf
# Processing Record 41 of Set 6 | kijang
# Processing Record 42 of Set 6 | sisimiut
# Processing Record 43 of Set 6 | lae
# Processing Record 44 of Set 6 | asau
# Processing Record 45 of Set 6 | galesong
# Processing Record 46 of Set 6 | ngunguru
# Processing Record 47 of Set 6 | kirakira
# Processing Record 48 of Set 6 | jaypur
# Processing Record 49 of Set 6 | vredendal
# Processing Record 50 of Set 6 | axim
# Processing Record 1 of Set 7 | zaragoza
# Processing Record 2 of Set 7 | salvador
# Processing Record 3 of Set 7 | praia
# Processing Record 4 of Set 7 | bulgan
# Processing Record 5 of Set 7 | lebedyn
# Processing Record 6 of Set 7 | yichang
# Processing Record 7 of Set 7 | pitimbu
# Processing Record 8 of Set 7 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 9 of Set 7 | kununurra
# Processing Record 10 of Set 7 | eugene
# Processing Record 11 of Set 7 | wanning
# Processing Record 12 of Set 7 | kysyl-syr
# Processing Record 13 of Set 7 | lata
# Processing Record 14 of Set 7 | alberton
# Processing Record 15 of Set 7 | sayat
# Processing Record 16 of Set 7 | lebu
# Processing Record 17 of Set 7 | baoning
# Processing Record 18 of Set 7 | sao filipe
# Processing Record 19 of Set 7 | poddorye
# Processing Record 20 of Set 7 | fayetteville
# Processing Record 21 of Set 7 | attawapiskat
# City not found. Skipping...
# Processing Record 22 of Set 7 | tsihombe
# City not found. Skipping...
# Processing Record 23 of Set 7 | beloha
# Processing Record 24 of Set 7 | verkhnyaya inta
# Processing Record 25 of Set 7 | plakhtiyivka
# Processing Record 26 of Set 7 | tyazhinskiy
# Processing Record 27 of Set 7 | touros
# Processing Record 28 of Set 7 | requena
# Processing Record 29 of Set 7 | amderma
# City not found. Skipping...
# Processing Record 30 of Set 7 | manono
# Processing Record 31 of Set 7 | bhadrachalam
# Processing Record 32 of Set 7 | farsund
# Processing Record 33 of Set 7 | sur
# Processing Record 34 of Set 7 | saint anthony
# Processing Record 35 of Set 7 | huarmey
# Processing Record 36 of Set 7 | pierre
# Processing Record 37 of Set 7 | mackenzie
# Processing Record 38 of Set 7 | tura
# Processing Record 39 of Set 7 | zhitikara
# City not found. Skipping...
# Processing Record 40 of Set 7 | franca
# Processing Record 41 of Set 7 | mehkerek
# Processing Record 42 of Set 7 | tawang
# Processing Record 43 of Set 7 | kedgwick
# Processing Record 44 of Set 7 | ramos arizpe
# Processing Record 45 of Set 7 | fairbanks
# Processing Record 46 of Set 7 | kenora
# Processing Record 47 of Set 7 | contamana
# Processing Record 48 of Set 7 | brigantine
# Processing Record 49 of Set 7 | san patricio
# Processing Record 50 of Set 7 | baykit
# Processing Record 1 of Set 8 | yoichi
# Processing Record 2 of Set 8 | boyolangu
# Processing Record 3 of Set 8 | toppenish
# Processing Record 4 of Set 8 | malacatepec
# Processing Record 5 of Set 8 | fort nelson
# Processing Record 6 of Set 8 | turukhansk
# Processing Record 7 of Set 8 | porto velho
# Processing Record 8 of Set 8 | tautira
# Processing Record 9 of Set 8 | chengde
# Processing Record 10 of Set 8 | clyde
# Processing Record 11 of Set 8 | concarneau
# Processing Record 12 of Set 8 | mbandaka
# Processing Record 13 of Set 8 | meulaboh
# Processing Record 14 of Set 8 | yumen
# Processing Record 15 of Set 8 | samusu
# City not found. Skipping...
# Processing Record 16 of Set 8 | galveston
# Processing Record 17 of Set 8 | yerbogachen
# Processing Record 18 of Set 8 | junin
# Processing Record 19 of Set 8 | pathein
# Processing Record 20 of Set 8 | aranos
# Processing Record 21 of Set 8 | guerrero negro
# Processing Record 22 of Set 8 | paita
# Processing Record 23 of Set 8 | plettenberg bay
# Processing Record 24 of Set 8 | lufilufi
# Processing Record 25 of Set 8 | fonte boa
# Processing Record 26 of Set 8 | belaya gora
# Processing Record 27 of Set 8 | hibbing
# Processing Record 28 of Set 8 | saurimo
# Processing Record 29 of Set 8 | alofi
# Processing Record 30 of Set 8 | muros
# Processing Record 31 of Set 8 | darhan
# Processing Record 32 of Set 8 | ostrovnoy
# Processing Record 33 of Set 8 | quilali
# Processing Record 34 of Set 8 | plainfield
# Processing Record 35 of Set 8 | vila velha
# Processing Record 36 of Set 8 | conceicao do araguaia
# Processing Record 37 of Set 8 | severo-yeniseyskiy
# Processing Record 38 of Set 8 | maghama
# City not found. Skipping...
# Processing Record 39 of Set 8 | ahipara
# Processing Record 40 of Set 8 | bathsheba
# Processing Record 41 of Set 8 | bur gabo
# City not found. Skipping...
# Processing Record 42 of Set 8 | vostok
# Processing Record 43 of Set 8 | sept-iles
# Processing Record 44 of Set 8 | kaoma
# Processing Record 45 of Set 8 | khromtau
# Processing Record 46 of Set 8 | hobyo
# Processing Record 47 of Set 8 | broken hill
# Processing Record 48 of Set 8 | huajuapan
# City not found. Skipping...
# Processing Record 49 of Set 8 | port lincoln
# Processing Record 50 of Set 8 | bilibino
# Processing Record 1 of Set 9 | esperance
# Processing Record 2 of Set 9 | tiruvottiyur
# City not found. Skipping...
# Processing Record 3 of Set 9 | quesnel
# Processing Record 4 of Set 9 | stephenville
# Processing Record 5 of Set 9 | kachikau
# City not found. Skipping...
# Processing Record 6 of Set 9 | kholtoson
# Processing Record 7 of Set 9 | atikokan
# Processing Record 8 of Set 9 | seoul
# Processing Record 9 of Set 9 | epe
# Processing Record 10 of Set 9 | tigil
# Processing Record 11 of Set 9 | abu samrah
# Processing Record 12 of Set 9 | hals
# Processing Record 13 of Set 9 | bayonne
# Processing Record 14 of Set 9 | ngaoundere
# Processing Record 15 of Set 9 | champerico
# Processing Record 16 of Set 9 | kawalu
# Processing Record 17 of Set 9 | nioro
# Processing Record 18 of Set 9 | saint-georges
# Processing Record 19 of Set 9 | utiroa
# City not found. Skipping...
# Processing Record 20 of Set 9 | timra
# Processing Record 21 of Set 9 | nykoping
# Processing Record 22 of Set 9 | taoudenni
# Processing Record 23 of Set 9 | ballina
# Processing Record 24 of Set 9 | hachinohe
# Processing Record 25 of Set 9 | simbahan
# Processing Record 26 of Set 9 | tavda
# Processing Record 27 of Set 9 | ksenyevka
# City not found. Skipping...
# Processing Record 28 of Set 9 | humberto de campos
# Processing Record 29 of Set 9 | north bend
# Processing Record 30 of Set 9 | japura
# Processing Record 31 of Set 9 | ilanskiy
# Processing Record 32 of Set 9 | marawi
# Processing Record 33 of Set 9 | redmond
# Processing Record 34 of Set 9 | mahibadhoo
# Processing Record 35 of Set 9 | clyde river
# Processing Record 36 of Set 9 | chippewa falls
# Processing Record 37 of Set 9 | songkhla
# Processing Record 38 of Set 9 | truth or consequences
# Processing Record 39 of Set 9 | behbahan
# Processing Record 40 of Set 9 | poltavka
# Processing Record 41 of Set 9 | nova aurora
# Processing Record 42 of Set 9 | halifax
# Processing Record 43 of Set 9 | te anau
# Processing Record 44 of Set 9 | senador jose porfirio
# Processing Record 45 of Set 9 | elban
# Processing Record 46 of Set 9 | richards bay
# Processing Record 47 of Set 9 | dashitou
# Processing Record 48 of Set 9 | oktyabrskoye
# Processing Record 49 of Set 9 | neyshabur
# Processing Record 50 of Set 9 | labuhan
# Processing Record 1 of Set 10 | marcona
# City not found. Skipping...
# Processing Record 2 of Set 10 | padampur
# Processing Record 3 of Set 10 | tecoanapa
# Processing Record 4 of Set 10 | nome
# Processing Record 5 of Set 10 | namwala
# Processing Record 6 of Set 10 | santa rosa
# Processing Record 7 of Set 10 | amarante do maranhao
# Processing Record 8 of Set 10 | abu zabad
# Processing Record 9 of Set 10 | labuan
# Processing Record 10 of Set 10 | fortuna
# Processing Record 11 of Set 10 | roebourne
# Processing Record 12 of Set 10 | grand gaube
# Processing Record 13 of Set 10 | boguchany
# Processing Record 14 of Set 10 | siocon
# Processing Record 15 of Set 10 | los gatos
# Processing Record 16 of Set 10 | meridian
# Processing Record 17 of Set 10 | bagdarin
# Processing Record 18 of Set 10 | codrington
# Processing Record 19 of Set 10 | cangzhou
# Processing Record 20 of Set 10 | la libertad
# Processing Record 21 of Set 10 | angoche
# Processing Record 22 of Set 10 | quatre cocos
# Processing Record 23 of Set 10 | komsomolskiy
# Processing Record 24 of Set 10 | sulurpeta
# City not found. Skipping...
# Processing Record 25 of Set 10 | coxim
# Processing Record 26 of Set 10 | muroto
# Processing Record 27 of Set 10 | bairiki
# Processing Record 28 of Set 10 | inawayan
# Processing Record 29 of Set 10 | kajaani
# Processing Record 30 of Set 10 | banjar
# Processing Record 31 of Set 10 | haga
# Processing Record 32 of Set 10 | monywa
# Processing Record 33 of Set 10 | aswan
# Processing Record 34 of Set 10 | tessalit
# Processing Record 35 of Set 10 | tutoia
# Processing Record 36 of Set 10 | kulhudhuffushi
# Processing Record 37 of Set 10 | laurel
# Processing Record 38 of Set 10 | tibacuy
# Processing Record 39 of Set 10 | saint-francois
# Processing Record 40 of Set 10 | hovd
# Processing Record 41 of Set 10 | mchinji
# Processing Record 42 of Set 10 | skibbereen
# Processing Record 43 of Set 10 | puerto cortes
# City not found. Skipping...
# Processing Record 44 of Set 10 | rosita
# Processing Record 45 of Set 10 | anastasiyevskaya
# Processing Record 46 of Set 10 | ruatoria
# City not found. Skipping...
# Processing Record 47 of Set 10 | huaiyuan
# Processing Record 48 of Set 10 | misratah
# Processing Record 49 of Set 10 | louisbourg
# City not found. Skipping...
# Processing Record 50 of Set 10 | mantua
# Processing Record 1 of Set 11 | kruisfontein
# Processing Record 2 of Set 11 | sonqor
# Processing Record 3 of Set 11 | daxian
# City not found. Skipping...
# Processing Record 4 of Set 11 | viedma
# Processing Record 5 of Set 11 | venado tuerto
# Processing Record 6 of Set 11 | hiroshima
# Processing Record 7 of Set 11 | umm durman
# City not found. Skipping...
# Processing Record 8 of Set 11 | matagami
# Processing Record 9 of Set 11 | pacific grove
# Processing Record 10 of Set 11 | kargasok
# Processing Record 11 of Set 11 | lusambo
# Processing Record 12 of Set 11 | gawler
# Processing Record 13 of Set 11 | baghmara
# Processing Record 14 of Set 11 | srednekolymsk
# Processing Record 15 of Set 11 | alamosa
# Processing Record 16 of Set 11 | luau
# Processing Record 17 of Set 11 | aanekoski
# Processing Record 18 of Set 11 | gat
# Processing Record 19 of Set 11 | keti bandar
# Processing Record 20 of Set 11 | mount pleasant
# Processing Record 21 of Set 11 | nouadhibou
# Processing Record 22 of Set 11 | opuwo
# Processing Record 23 of Set 11 | dekernes
# Processing Record 24 of Set 11 | los llanos de aridane
# Processing Record 25 of Set 11 | sinnamary
# Processing Record 26 of Set 11 | uglegorsk
# Processing Record 27 of Set 11 | hirara
# Processing Record 28 of Set 11 | bonthe
# Processing Record 29 of Set 11 | high level
# Processing Record 30 of Set 11 | hualmay
# Processing Record 31 of Set 11 | nakusp
# Processing Record 32 of Set 11 | balakovo
# Processing Record 33 of Set 11 | shenzhen
# Processing Record 34 of Set 11 | presov
# Processing Record 35 of Set 11 | gamba
# Processing Record 36 of Set 11 | bom jesus
# Processing Record 37 of Set 11 | priargunsk
# Processing Record 38 of Set 11 | kazalinsk
# City not found. Skipping...
# Processing Record 39 of Set 11 | rypefjord
# Processing Record 40 of Set 11 | iqaluit
# Processing Record 41 of Set 11 | xining
# Processing Record 42 of Set 11 | flin flon
# Processing Record 43 of Set 11 | lasa
# Processing Record 44 of Set 11 | tabursuq
# Processing Record 45 of Set 11 | meadow lake
# Processing Record 46 of Set 11 | tunduru
# City not found. Skipping...
# Processing Record 47 of Set 11 | sakaiminato
# Processing Record 48 of Set 11 | comodoro rivadavia
# Processing Record 49 of Set 11 | svrljig
# Processing Record 50 of Set 11 | otorohanga
# Processing Record 1 of Set 12 | morwell
# Processing Record 2 of Set 12 | huangmei
# Processing Record 3 of Set 12 | porterville
# Processing Record 4 of Set 12 | barahona
# Processing Record 5 of Set 12 | burriana
# Processing Record 6 of Set 12 | storforshei
# Processing Record 7 of Set 12 | pemangkat
# Processing Record 8 of Set 12 | valdivia
# Processing Record 9 of Set 12 | akyab
# Processing Record 10 of Set 12 | maningrida
# Processing Record 11 of Set 12 | kavieng
# Processing Record 12 of Set 12 | muncar
# Processing Record 13 of Set 12 | ocos
# Processing Record 14 of Set 12 | hofn
# Processing Record 15 of Set 12 | wahran
# City not found. Skipping...
# Processing Record 16 of Set 12 | harrisburg
# Processing Record 17 of Set 12 | guicheng
# City not found. Skipping...
# Processing Record 18 of Set 12 | kamenka
# Processing Record 19 of Set 12 | bolungarvik
# City not found. Skipping...
# Processing Record 20 of Set 12 | armidale
# Processing Record 21 of Set 12 | orcopampa
# Processing Record 22 of Set 12 | yeppoon
# Processing Record 23 of Set 12 | dzhusaly
# City not found. Skipping...
# Processing Record 24 of Set 12 | novo aripuana
# Processing Record 25 of Set 12 | kollumerland
# City not found. Skipping...
# Processing Record 26 of Set 12 | dubasari
# Processing Record 27 of Set 12 | joaquim gomes
# Processing Record 28 of Set 12 | forbes
# Processing Record 29 of Set 12 | sao geraldo do araguaia
# Processing Record 30 of Set 12 | belmonte
# Processing Record 31 of Set 12 | wentzville
# Processing Record 32 of Set 12 | mezen
# Processing Record 33 of Set 12 | vilyuysk
# Processing Record 34 of Set 12 | ken caryl
# Processing Record 35 of Set 12 | saint-augustin
# Processing Record 36 of Set 12 | hailar
# Processing Record 37 of Set 12 | bandarbeyla
# Processing Record 38 of Set 12 | watsa
# Processing Record 39 of Set 12 | sindor
# Processing Record 40 of Set 12 | westport
# Processing Record 41 of Set 12 | toamasina
# Processing Record 42 of Set 12 | verkh-usugli
# Processing Record 43 of Set 12 | korla
# Processing Record 44 of Set 12 | pangai
# Processing Record 45 of Set 12 | brateiu
# Processing Record 46 of Set 12 | koungou
# Processing Record 47 of Set 12 | cap malheureux
# Processing Record 48 of Set 12 | asyut
# Processing Record 49 of Set 12 | ketchikan
# Processing Record 50 of Set 12 | novoagansk
# Processing Record 1 of Set 13 | jalu
# Processing Record 2 of Set 13 | tomatlan
# Processing Record 3 of Set 13 | tezu
# Processing Record 4 of Set 13 | las vegas
# Processing Record 5 of Set 13 | birao
# Processing Record 6 of Set 13 | brae
# Processing Record 7 of Set 13 | zhovtneve
# Processing Record 8 of Set 13 | morehead
# Processing Record 9 of Set 13 | granard
# Processing Record 10 of Set 13 | buon me thuot
# City not found. Skipping...
# Processing Record 11 of Set 13 | dzaoudzi
# Processing Record 12 of Set 13 | kavaratti
# Processing Record 13 of Set 13 | malwan
# City not found. Skipping...
# Processing Record 14 of Set 13 | west bay
# Processing Record 15 of Set 13 | kuryk
# Processing Record 16 of Set 13 | mareeba
# Processing Record 17 of Set 13 | hendijan
# City not found. Skipping...
# Processing Record 18 of Set 13 | karatau
# Processing Record 19 of Set 13 | melchor de mencos
# Processing Record 20 of Set 13 | vorukh
# Processing Record 21 of Set 13 | cururupu
# Processing Record 22 of Set 13 | plouzane
# Processing Record 23 of Set 13 | dicabisagan
# Processing Record 24 of Set 13 | mabaruma
# Processing Record 25 of Set 13 | kopavogur
# Processing Record 26 of Set 13 | miramar
# Processing Record 27 of Set 13 | poum
# Processing Record 28 of Set 13 | boende
# Processing Record 29 of Set 13 | tahe
# Processing Record 30 of Set 13 | itarema
# Processing Record 31 of Set 13 | oyonnax
# Processing Record 32 of Set 13 | santa isabel
# Processing Record 33 of Set 13 | nabire
# Processing Record 34 of Set 13 | goundam
# Processing Record 35 of Set 13 | ullapool
# Processing Record 36 of Set 13 | nicoya
# Processing Record 37 of Set 13 | cervo
# Processing Record 38 of Set 13 | mindelo
# Processing Record 39 of Set 13 | amravati
# Processing Record 40 of Set 13 | kochetok
# Processing Record 41 of Set 13 | san nicolas
# Processing Record 42 of Set 13 | tongchuan
# Processing Record 43 of Set 13 | dehloran
# Processing Record 44 of Set 13 | oropoli
# Processing Record 45 of Set 13 | george
# Processing Record 46 of Set 13 | xuddur
# Processing Record 47 of Set 13 | palana
# Processing Record 48 of Set 13 | jizan
# Processing Record 49 of Set 13 | bangolo
# Processing Record 50 of Set 13 | sidi ali
# Processing Record 1 of Set 14 | muret
# Processing Record 2 of Set 14 | oyama
# Processing Record 3 of Set 14 | najran
# Processing Record 4 of Set 14 | red deer
# Processing Record 5 of Set 14 | jadu
# Processing Record 6 of Set 14 | plymouth
# Processing Record 7 of Set 14 | ventaquemada
# Processing Record 8 of Set 14 | sembe
# Processing Record 9 of Set 14 | sao gabriel da cachoeira
# Processing Record 10 of Set 14 | thunder bay
# Processing Record 11 of Set 14 | pisco
# Processing Record 12 of Set 14 | ikornnes
# Processing Record 13 of Set 14 | ossora
# Processing Record 14 of Set 14 | berkakit
# Processing Record 15 of Set 14 | damaturu
# Processing Record 16 of Set 14 | polyanka
# Processing Record 17 of Set 14 | cabinda
# Processing Record 18 of Set 14 | yugorsk
# Processing Record 19 of Set 14 | caucaia
# Processing Record 20 of Set 14 | anshun
# Processing Record 21 of Set 14 | urucui
# Processing Record 22 of Set 14 | calvinia
# Processing Record 23 of Set 14 | mehamn
# Processing Record 24 of Set 14 | caninde de sao francisco
# Processing Record 25 of Set 14 | palmas bellas
# Processing Record 26 of Set 14 | amboasary
# Processing Record 27 of Set 14 | nelson bay
# Processing Record 28 of Set 14 | grand centre
# City not found. Skipping...
# Processing Record 29 of Set 14 | sinop
# Processing Record 30 of Set 14 | teguldet
# Processing Record 31 of Set 14 | sambava
# Processing Record 32 of Set 14 | ayan
# Processing Record 33 of Set 14 | rocha
# Processing Record 34 of Set 14 | sicamous
# Processing Record 35 of Set 14 | lincoln
# Processing Record 36 of Set 14 | dulovo
# Processing Record 37 of Set 14 | manakara
# Processing Record 38 of Set 14 | pervomayskoye
# Processing Record 39 of Set 14 | colares
# Processing Record 40 of Set 14 | yueyang
# Processing Record 41 of Set 14 | gbarnga
# Processing Record 42 of Set 14 | cayenne
# Processing Record 43 of Set 14 | gemena
# Processing Record 44 of Set 14 | bad nenndorf
# Processing Record 45 of Set 14 | bossembele
# City not found. Skipping...
# Processing Record 46 of Set 14 | wuning
# Processing Record 47 of Set 14 | davila
# Processing Record 48 of Set 14 | hazebrouck
# Processing Record 49 of Set 14 | bhadasar
# Processing Record 50 of Set 14 | gazli
# Processing Record 1 of Set 15 | chalchihuites
# Processing Record 2 of Set 15 | amot
# Processing Record 3 of Set 15 | shaturtorf
# Processing Record 4 of Set 15 | manokwari
# Processing Record 5 of Set 15 | sakakah
# Processing Record 6 of Set 15 | pokrovka
# Processing Record 7 of Set 15 | watertown
# Processing Record 8 of Set 15 | veraval
# Processing Record 9 of Set 15 | homer
# Processing Record 10 of Set 15 | castle bruce
# Processing Record 11 of Set 15 | kampot
# Processing Record 12 of Set 15 | macas
# Processing Record 13 of Set 15 | guiratinga
# Processing Record 14 of Set 15 | coos bay
# Processing Record 15 of Set 15 | vestmannaeyjar
# Processing Record 16 of Set 15 | nehe
# Processing Record 17 of Set 15 | tombouctou
# Processing Record 18 of Set 15 | berezovyy
# Processing Record 19 of Set 15 | paredon
# Processing Record 20 of Set 15 | collingswood
# Processing Record 21 of Set 15 | fairmont
# Processing Record 22 of Set 15 | pangkalanbuun
# Processing Record 23 of Set 15 | ravar
# Processing Record 24 of Set 15 | marrakesh
# Processing Record 25 of Set 15 | aldan
# Processing Record 26 of Set 15 | nikel
# Processing Record 27 of Set 15 | turkistan
# Processing Record 28 of Set 15 | pyapon
# Processing Record 29 of Set 15 | tateyama
# Processing Record 30 of Set 15 | nizhnevartovsk
# Processing Record 31 of Set 15 | severodvinsk
# Processing Record 32 of Set 15 | mayor pablo lagerenza
# Processing Record 33 of Set 15 | berdigestyakh
# Processing Record 34 of Set 15 | kapustin yar
# Processing Record 35 of Set 15 | novyy urengoy
# Processing Record 36 of Set 15 | dagana
# Processing Record 37 of Set 15 | khomutovo
# Processing Record 38 of Set 15 | usinsk
# Processing Record 39 of Set 15 | runkel
# Processing Record 40 of Set 15 | hanamaki
# Processing Record 41 of Set 15 | aflu
# City not found. Skipping...
# Processing Record 42 of Set 15 | flagstaff
# Processing Record 43 of Set 15 | kapit
# Processing Record 44 of Set 15 | shingu
# Processing Record 45 of Set 15 | siniscola
# Processing Record 46 of Set 15 | kemijarvi
# Processing Record 47 of Set 15 | turtas
# Processing Record 48 of Set 15 | aitape
# Processing Record 49 of Set 15 | matara
# Processing Record 50 of Set 15 | brockville
# Processing Record 1 of Set 16 | morros
# Processing Record 2 of Set 16 | nemuro
# Processing Record 3 of Set 16 | tabukiniberu
# City not found. Skipping...
# Processing Record 4 of Set 16 | richmond
# Processing Record 5 of Set 16 | gloversville
# Processing Record 6 of Set 16 | paka
# Processing Record 7 of Set 16 | coahuayana
# Processing Record 8 of Set 16 | kayes
# Processing Record 9 of Set 16 | jaru
# Processing Record 10 of Set 16 | sitrah
# Processing Record 11 of Set 16 | port shepstone
# Processing Record 12 of Set 16 | antalaha
# Processing Record 13 of Set 16 | kirovsk
# Processing Record 14 of Set 16 | pleasant point
# Processing Record 15 of Set 16 | hungund
# Processing Record 16 of Set 16 | umm lajj
# Processing Record 17 of Set 16 | bayburt
# Processing Record 18 of Set 16 | tambo
# Processing Record 19 of Set 16 | inverness
# Processing Record 20 of Set 16 | segou
# Processing Record 21 of Set 16 | jamame
# Processing Record 22 of Set 16 | neuquen
# Processing Record 23 of Set 16 | gazanjyk
# Processing Record 24 of Set 16 | sturgis
# Processing Record 25 of Set 16 | tatarsk
# Processing Record 26 of Set 16 | rio gallegos
# Processing Record 27 of Set 16 | maniitsoq
# Processing Record 28 of Set 16 | kaohsiung
# Processing Record 29 of Set 16 | wesselsbron
# Processing Record 30 of Set 16 | ukiah
# Processing Record 31 of Set 16 | moerai
# Processing Record 32 of Set 16 | pochutla
# Processing Record 33 of Set 16 | villa union
# Processing Record 34 of Set 16 | igrim
# Processing Record 35 of Set 16 | sobolevo
# Processing Record 36 of Set 16 | krasnousolskiy
# City not found. Skipping...
# Processing Record 37 of Set 16 | alice springs
# Processing Record 38 of Set 16 | formosa
# Processing Record 39 of Set 16 | voi
# Processing Record 40 of Set 16 | ampanihy
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 733

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        Sangar  63.9242  127.4739    -63.58       100          79
# 1          Doka  13.5167   35.7667     79.45        32          64
# 2       Lichuan  30.3000  108.8500     46.80        97          98
# 3        Tromso  69.6496   18.9570     35.62        87          75
# 4    Harrismith -28.2728   29.1295     64.83        36           2
# 5       Ushuaia -54.8000  -68.3000     58.62        54          40
# 6       Rikitea -23.1203 -134.9692     78.21        76           7
# 7  Batemans Bay -35.7167  150.1833     63.45        96          29
# 8         Kapaa  22.0752 -159.3190     66.18        90           0
# 9  Saint-Joseph -21.3667   55.6167     77.38        78          77
#
#    Wind Speed Country Current Description
# 0        0.87      RU       broken clouds
# 1       11.07      SD       broken clouds
# 2        3.22      CN     overcast clouds
# 3       13.80      NO          light snow
# 4        5.59      ZA           clear sky
# 5       24.16      AR    scattered clouds
# 6       20.42      PF          light rain
# 7        3.47      AU    scattered clouds
# 8        6.91      US           clear sky
# 9       10.67      RE       broken clouds

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Country', 'Current Description'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]

# Recreate the DataFrame by using the new column order
final_city_data_df = city_data_df[new_column_order]

# Display sample data
final_city_data_df.head()
# Out:
#          City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0      Sangar      RU  63.9242  127.4739    -63.58       100          79
# 1        Doka      SD  13.5167   35.7667     79.45        32          64
# 2     Lichuan      CN  30.3000  108.8500     46.80        97          98
# 3      Tromso      NO  69.6496   18.9570     35.62        87          75
# 4  Harrismith      ZA -28.2728   29.1295     64.83        36           2
#
#    Wind Speed Current Description
# 0        0.87       broken clouds
# 1       11.07       broken clouds
# 2        3.22     overcast clouds
# 3       13.80          light snow
# 4        5.59           clear sky

# %%
# Display the data types of each column by using the dtypes Pandas function
final_city_data_df.dtypes
# Out:
# City                    object
# Country                 object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Current Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
output_data_file = "../Weather_Database/WeatherPy_Database.csv"

# Export the city_data DataFrame into a CSV file
city_data_df.to_csv(output_data_file, index_label="City_ID")
